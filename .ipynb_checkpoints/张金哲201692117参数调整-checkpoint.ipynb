# %%
import os, shutil
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF
config = tf.ConfigProto(gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.2))
sess = tf.Session(config=config)
KTF.set_session(sess)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
base_dir = './dogImages'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'valid')
test_dir = os.path.join(base_dir, 'test')
train_plus_dir=os.path.join(base_dir, 'train_plus')

# %% [markdown]
# # 增强数据集的操作

# %%
# if not os.path.exists(train_plus_dir):
#     shutil.copytree(train_dir,train_plus_dir)
# for kind in os.listdir(train_plus_dir):
#     kind_dir=os.path.join(train_plus_dir, kind)
#     if len(os.listdir(kind_dir))*4 < 5*len([x for x in os.listdir(kind_dir) if x.startswith('pic_plus')])+5:
#         continue
#     for pic in os.listdir(kind_dir):
#         pic_dir=os.path.join(kind_dir, pic)
#         if not pic.endswith(".jpg"):
#             continue
#         if pic.startswith('pic_plus'):
#             os.remove(pic_dir)
#             continue
#         print (pic_dir)
#         image = load_img(pic_dir)
#         image = img_to_array(image)
#         image = np.expand_dims(image, axis=0)
#         aug = ImageDataGenerator(rotation_range=30, 
#                                  width_shift_range=0.1,
#                                  height_shift_range=0.1, 
#                                  shear_range=0.1, 
#                                  zoom_range=0.2,
#                                  horizontal_flip=True, 
#                                  fill_mode="nearest")
#         total = 0
#         imageGen = aug.flow(image, batch_size=1, 
#                             save_to_dir=kind_dir,
#                             save_prefix="pic_plus", 
#                             save_format="jpg")
#         print (imageGen)
#         for image in imageGen:
#         # increment our counter
#             total += 1
#             # if we have reached 4 examples, break from the loop
#             if total == 4:
#                 break

# %%
train_dir=train_plus_dir

# %%
from keras.applications import VGG16

conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))
conv_base.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 150, 150, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(133, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_4 (Dense)              (None, 133)               34181
# =================================================================
# Total params: 16,846,277
# Trainable params: 16,846,277
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_base.trainable = False

# %%
from keras import optimizers
# lr: float >= 0. 学习率 Learning rate

# momentum: float >= 0. 参数更新动量 parameter updates momentum

# decay: float >= 0. 学习率每次更新的下降率 Learning rate decay over each update

# nesterov: boolean. 是否应用 Nesterov 动量 whether to apply Nesterov momentum
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
from keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(150, 150),
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=100,
        class_mode='categorical')
validation_generator
print(validation_generator.class_indices)
np.save('labels.npy', validation_generator.class_indices)
# Out:
# Found 20417 images belonging to 133 classes.
# Found 835 images belonging to 133 classes.
# {'001.Affenpinscher': 0, '002.Afghan_hound': 1, '003.Airedale_terrier': 2, '004.Akita': 3, '005.Alaskan_malamute': 4, '006.American_eskimo_dog': 5, '007.American_foxhound': 6, '008.American_staffordshire_terrier': 7, '009.American_water_spaniel': 8, '010.Anatolian_shepherd_dog': 9, '011.Australian_cattle_dog': 10, '012.Australian_shepherd': 11, '013.Australian_terrier': 12, '014.Basenji': 13, '015.Basset_hound': 14, '016.Beagle': 15, '017.Bearded_collie': 16, '018.Beauceron': 17, '019.Bedlington_terrier': 18, '020.Belgian_malinois': 19, '021.Belgian_sheepdog': 20, '022.Belgian_tervuren': 21, '023.Bernese_mountain_dog': 22, '024.Bichon_frise': 23, '025.Black_and_tan_coonhound': 24, '026.Black_russian_terrier': 25, '027.Bloodhound': 26, '028.Bluetick_coonhound': 27, '029.Border_collie': 28, '030.Border_terrier': 29, '031.Borzoi': 30, '032.Boston_terrier': 31, '033.Bouvier_des_flandres': 32, '034.Boxer': 33, '035.Boykin_spaniel': 34, '036.Briard': 35, '037.Brittany': 36, '038.Brussels_griffon': 37, '039.Bull_terrier': 38, '040.Bulldog': 39, '041.Bullmastiff': 40, '042.Cairn_terrier': 41, '043.Canaan_dog': 42, '044.Cane_corso': 43, '045.Cardigan_welsh_corgi': 44, '046.Cavalier_king_charles_spaniel': 45, '047.Chesapeake_bay_retriever': 46, '048.Chihuahua': 47, '049.Chinese_crested': 48, '050.Chinese_shar-pei': 49, '051.Chow_chow': 50, '052.Clumber_spaniel': 51, '053.Cocker_spaniel': 52, '054.Collie': 53, '055.Curly-coated_retriever': 54, '056.Dachshund': 55, '057.Dalmatian': 56, '058.Dandie_dinmont_terrier': 57, '059.Doberman_pinscher': 58, '060.Dogue_de_bordeaux': 59, '061.English_cocker_spaniel': 60, '062.English_setter': 61, '063.English_springer_spaniel': 62, '064.English_toy_spaniel': 63, '065.Entlebucher_mountain_dog': 64, '066.Field_spaniel': 65, '067.Finnish_spitz': 66, '068.Flat-coated_retriever': 67, '069.French_bulldog': 68, '070.German_pinscher': 69, '071.German_shepherd_dog': 70, '072.German_shorthaired_pointer': 71, '073.German_wirehaired_pointer': 72, '074.Giant_schnauzer': 73, '075.Glen_of_imaal_terrier': 74, '076.Golden_retriever': 75, '077.Gordon_setter': 76, '078.Great_dane': 77, '079.Great_pyrenees': 78, '080.Greater_swiss_mountain_dog': 79, '081.Greyhound': 80, '082.Havanese': 81, '083.Ibizan_hound': 82, '084.Icelandic_sheepdog': 83, '085.Irish_red_and_white_setter': 84, '086.Irish_setter': 85, '087.Irish_terrier': 86, '088.Irish_water_spaniel': 87, '089.Irish_wolfhound': 88, '090.Italian_greyhound': 89, '091.Japanese_chin': 90, '092.Keeshond': 91, '093.Kerry_blue_terrier': 92, '094.Komondor': 93, '095.Kuvasz': 94, '096.Labrador_retriever': 95, '097.Lakeland_terrier': 96, '098.Leonberger': 97, '099.Lhasa_apso': 98, '100.Lowchen': 99, '101.Maltese': 100, '102.Manchester_terrier': 101, '103.Mastiff': 102, '104.Miniature_schnauzer': 103, '105.Neapolitan_mastiff': 104, '106.Newfoundland': 105, '107.Norfolk_terrier': 106, '108.Norwegian_buhund': 107, '109.Norwegian_elkhound': 108, '110.Norwegian_lundehund': 109, '111.Norwich_terrier': 110, '112.Nova_scotia_duck_tolling_retriever': 111, '113.Old_english_sheepdog': 112, '114.Otterhound': 113, '115.Papillon': 114, '116.Parson_russell_terrier': 115, '117.Pekingese': 116, '118.Pembroke_welsh_corgi': 117, '119.Petit_basset_griffon_vendeen': 118, '120.Pharaoh_hound': 119, '121.Plott': 120, '122.Pointer': 121, '123.Pomeranian': 122, '124.Poodle': 123, '125.Portuguese_water_dog': 124, '126.Saint_bernard': 125, '127.Silky_terrier': 126, '128.Smooth_fox_terrier': 127, '129.Tibetan_mastiff': 128, '130.Welsh_springer_spaniel': 129, '131.Wirehaired_pointing_griffon': 130, '132.Xoloitzcuintli': 131, '133.Yorkshire_terrier': 132}

# %%
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (20, 150, 150, 3)
# labels batch shape: (20, 133)

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from PIL import ImageFile
early_stopping = EarlyStopping(monitor='val_loss',patience=7) 
ImageFile.LOAD_TRUNCATED_IMAGES = True
checkpointer = ModelCheckpoint(filepath='dogskind.model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
history = model.fit_generator(train_generator,
      steps_per_epoch=100,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=50, 
      callbacks=[early_stopping,checkpointer], 
      verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 53s 534ms/step - loss: 4.9105 - acc: 0.0185 - val_loss: 4.8144 - val_acc: 0.0366
#
# Epoch 00001: val_loss improved from inf to 4.81436, saving model to dogskind.model.weights.best.hdf5
# Epoch 2/100
# 100/100 [==============================] - 49s 490ms/step - loss: 4.7337 - acc: 0.0360 - val_loss: 4.6791 - val_acc: 0.0425
#
# Epoch 00002: val_loss improved from 4.81436 to 4.67913, saving model to dogskind.model.weights.best.hdf5
# Epoch 3/100
# 100/100 [==============================] - 50s 497ms/step - loss: 4.5892 - acc: 0.0630 - val_loss: 4.5125 - val_acc: 0.0744
#
# Epoch 00003: val_loss improved from 4.67913 to 4.51248, saving model to dogskind.model.weights.best.hdf5
# Epoch 4/100
# 100/100 [==============================] - 50s 497ms/step - loss: 4.4316 - acc: 0.0915 - val_loss: 4.3598 - val_acc: 0.0944
#
# Epoch 00004: val_loss improved from 4.51248 to 4.35977, saving model to dogskind.model.weights.best.hdf5
# Epoch 5/100
# 100/100 [==============================] - 52s 515ms/step - loss: 4.2617 - acc: 0.1155 - val_loss: 4.2113 - val_acc: 0.1170
#
# Epoch 00005: val_loss improved from 4.35977 to 4.21133, saving model to dogskind.model.weights.best.hdf5
# Epoch 6/100
# 100/100 [==============================] - 50s 502ms/step - loss: 4.1130 - acc: 0.1220 - val_loss: 4.0618 - val_acc: 0.1317
#
# Epoch 00006: val_loss improved from 4.21133 to 4.06176, saving model to dogskind.model.weights.best.hdf5
# Epoch 7/100
# 100/100 [==============================] - 51s 510ms/step - loss: 3.9117 - acc: 0.1680 - val_loss: 3.9774 - val_acc: 0.1307
#
# Epoch 00007: val_loss improved from 4.06176 to 3.97740, saving model to dogskind.model.weights.best.hdf5
# Epoch 8/100
# 100/100 [==============================] - 50s 501ms/step - loss: 3.7963 - acc: 0.1755 - val_loss: 3.8110 - val_acc: 0.1657
#
# Epoch 00008: val_loss improved from 3.97740 to 3.81104, saving model to dogskind.model.weights.best.hdf5
# Epoch 9/100
# 100/100 [==============================] - 50s 505ms/step - loss: 3.7136 - acc: 0.1885 - val_loss: 3.7285 - val_acc: 0.1657
#
# Epoch 00009: val_loss improved from 3.81104 to 3.72846, saving model to dogskind.model.weights.best.hdf5
# Epoch 10/100
# 100/100 [==============================] - 50s 501ms/step - loss: 3.5807 - acc: 0.2055 - val_loss: 3.6470 - val_acc: 0.1876
#
# Epoch 00010: val_loss improved from 3.72846 to 3.64697, saving model to dogskind.model.weights.best.hdf5
# Epoch 11/100
# 100/100 [==============================] - 50s 497ms/step - loss: 3.2303 - acc: 0.3120 - val_loss: 3.5425 - val_acc: 0.1993
#
# Epoch 00011: val_loss improved from 3.64697 to 3.54246, saving model to dogskind.model.weights.best.hdf5
# Epoch 12/100
# 100/100 [==============================] - 53s 528ms/step - loss: 3.1439 - acc: 0.2935 - val_loss: 3.4882 - val_acc: 0.2156
#
# Epoch 00012: val_loss improved from 3.54246 to 3.48818, saving model to dogskind.model.weights.best.hdf5
# Epoch 13/100
# 100/100 [==============================] - 49s 489ms/step - loss: 3.0708 - acc: 0.3130 - val_loss: 3.4414 - val_acc: 0.2104
#
# Epoch 00013: val_loss improved from 3.48818 to 3.44144, saving model to dogskind.model.weights.best.hdf5
# Epoch 14/100
# 100/100 [==============================] - 51s 506ms/step - loss: 2.9754 - acc: 0.3415 - val_loss: 3.4196 - val_acc: 0.2182
#
# Epoch 00014: val_loss improved from 3.44144 to 3.41961, saving model to dogskind.model.weights.best.hdf5
# Epoch 15/100
# 100/100 [==============================] - 53s 525ms/step - loss: 2.9417 - acc: 0.3275 - val_loss: 3.2955 - val_acc: 0.2373
#
# Epoch 00015: val_loss improved from 3.41961 to 3.29553, saving model to dogskind.model.weights.best.hdf5
# Epoch 16/100
# 100/100 [==============================] - 52s 518ms/step - loss: 2.8514 - acc: 0.3385 - val_loss: 3.2856 - val_acc: 0.2233
#
# Epoch 00016: val_loss improved from 3.29553 to 3.28556, saving model to dogskind.model.weights.best.hdf5
# Epoch 17/100
# 100/100 [==============================] - 51s 507ms/step - loss: 2.8152 - acc: 0.3460 - val_loss: 3.2237 - val_acc: 0.2295
#
# Epoch 00017: val_loss improved from 3.28556 to 3.22371, saving model to dogskind.model.weights.best.hdf5
# Epoch 18/100
# 100/100 [==============================] - 48s 482ms/step - loss: 2.7957 - acc: 0.3565 - val_loss: 3.1843 - val_acc: 0.2295
#
# Epoch 00018: val_loss improved from 3.22371 to 3.18432, saving model to dogskind.model.weights.best.hdf5
# Epoch 19/100
# 100/100 [==============================] - 51s 508ms/step - loss: 2.6576 - acc: 0.3855 - val_loss: 3.1244 - val_acc: 0.2385
#
# Epoch 00019: val_loss improved from 3.18432 to 3.12439, saving model to dogskind.model.weights.best.hdf5
# Epoch 20/100
# 100/100 [==============================] - 49s 494ms/step - loss: 2.7253 - acc: 0.3610 - val_loss: 3.1130 - val_acc: 0.2640
#
# Epoch 00020: val_loss improved from 3.12439 to 3.11301, saving model to dogskind.model.weights.best.hdf5
# Epoch 21/100
# 100/100 [==============================] - 51s 511ms/step - loss: 2.3399 - acc: 0.4695 - val_loss: 3.0611 - val_acc: 0.2618
#
# Epoch 00021: val_loss improved from 3.11301 to 3.06109, saving model to dogskind.model.weights.best.hdf5
# Epoch 22/100
# 100/100 [==============================] - 51s 507ms/step - loss: 2.2814 - acc: 0.4780 - val_loss: 3.0293 - val_acc: 0.2638
#
# Epoch 00022: val_loss improved from 3.06109 to 3.02931, saving model to dogskind.model.weights.best.hdf5
# Epoch 23/100
# 100/100 [==============================] - 50s 498ms/step - loss: 2.2466 - acc: 0.4905 - val_loss: 3.0117 - val_acc: 0.2633
#
# Epoch 00023: val_loss improved from 3.02931 to 3.01172, saving model to dogskind.model.weights.best.hdf5
# Epoch 24/100
# 100/100 [==============================] - 50s 501ms/step - loss: 2.2505 - acc: 0.4910 - val_loss: 2.9716 - val_acc: 0.2857
#
# Epoch 00024: val_loss improved from 3.01172 to 2.97163, saving model to dogskind.model.weights.best.hdf5
# Epoch 25/100
# 100/100 [==============================] - 51s 505ms/step - loss: 2.2132 - acc: 0.4995 - val_loss: 2.9576 - val_acc: 0.2710
#
# Epoch 00025: val_loss improved from 2.97163 to 2.95756, saving model to dogskind.model.weights.best.hdf5
# Epoch 26/100
# 100/100 [==============================] - 51s 507ms/step - loss: 2.2206 - acc: 0.4775 - val_loss: 2.9170 - val_acc: 0.2805
#
# Epoch 00026: val_loss improved from 2.95756 to 2.91703, saving model to dogskind.model.weights.best.hdf5
# Epoch 27/100
# 100/100 [==============================] - 49s 488ms/step - loss: 2.1823 - acc: 0.4785 - val_loss: 2.8829 - val_acc: 0.2946
#
# Epoch 00027: val_loss improved from 2.91703 to 2.88286, saving model to dogskind.model.weights.best.hdf5
# Epoch 28/100
# 100/100 [==============================] - 52s 521ms/step - loss: 2.1420 - acc: 0.4970 - val_loss: 2.8713 - val_acc: 0.2785
#
# Epoch 00028: val_loss improved from 2.88286 to 2.87135, saving model to dogskind.model.weights.best.hdf5
# Epoch 29/100
# 100/100 [==============================] - 51s 509ms/step - loss: 2.1474 - acc: 0.4895 - val_loss: 2.8456 - val_acc: 0.2900
#
# Epoch 00029: val_loss improved from 2.87135 to 2.84557, saving model to dogskind.model.weights.best.hdf5
# Epoch 30/100
# 100/100 [==============================] - 51s 508ms/step - loss: 2.1144 - acc: 0.4930 - val_loss: 2.8674 - val_acc: 0.3001
#
# Epoch 00030: val_loss did not improve from 2.84557
# Epoch 31/100
# 100/100 [==============================] - 53s 526ms/step - loss: 1.8141 - acc: 0.6010 - val_loss: 2.8354 - val_acc: 0.2928
#
# Epoch 00031: val_loss improved from 2.84557 to 2.83540, saving model to dogskind.model.weights.best.hdf5
# Epoch 32/100
# 100/100 [==============================] - 50s 503ms/step - loss: 1.8156 - acc: 0.5920 - val_loss: 2.7659 - val_acc: 0.3161
#
# Epoch 00032: val_loss improved from 2.83540 to 2.76592, saving model to dogskind.model.weights.best.hdf5
# Epoch 33/100
# 100/100 [==============================] - 51s 505ms/step - loss: 1.7967 - acc: 0.5935 - val_loss: 2.7826 - val_acc: 0.3126
#
# Epoch 00033: val_loss did not improve from 2.76592
# Epoch 34/100
# 100/100 [==============================] - 50s 500ms/step - loss: 1.7559 - acc: 0.6040 - val_loss: 2.7815 - val_acc: 0.3025
#
# Epoch 00034: val_loss did not improve from 2.76592
# Epoch 35/100
# 100/100 [==============================] - 49s 494ms/step - loss: 1.7166 - acc: 0.6025 - val_loss: 2.8025 - val_acc: 0.2889
# Epoch 00035: val_loss did not improve from 2.76592
# Epoch 36/100
# 100/100 [==============================] - 50s 499ms/step - loss: 1.7132 - acc: 0.6155 - val_loss: 2.7526 - val_acc: 0.3165
#
# Epoch 00036: val_loss improved from 2.76592 to 2.75260, saving model to dogskind.model.weights.best.hdf5
# Epoch 37/100
# 100/100 [==============================] - 51s 505ms/step - loss: 1.7104 - acc: 0.6075 - val_loss: 2.7384 - val_acc: 0.3204
#
# Epoch 00037: val_loss improved from 2.75260 to 2.73839, saving model to dogskind.model.weights.best.hdf5
# Epoch 38/100
# 100/100 [==============================] - 51s 511ms/step - loss: 1.7250 - acc: 0.6015 - val_loss: 2.7077 - val_acc: 0.3406
#
# Epoch 00038: val_loss improved from 2.73839 to 2.70768, saving model to dogskind.model.weights.best.hdf5
# Epoch 39/100
# 100/100 [==============================] - 49s 491ms/step - loss: 1.6785 - acc: 0.6030 - val_loss: 2.7067 - val_acc: 0.3149
#
# Epoch 00039: val_loss improved from 2.70768 to 2.70673, saving model to dogskind.model.weights.best.hdf5
# Epoch 40/100
# 100/100 [==============================] - 50s 498ms/step - loss: 1.6914 - acc: 0.5975 - val_loss: 2.6931 - val_acc: 0.3184
#
# Epoch 00040: val_loss improved from 2.70673 to 2.69310, saving model to dogskind.model.weights.best.hdf5
# Epoch 41/100
# 100/100 [==============================] - 50s 499ms/step - loss: 1.3610 - acc: 0.7120 - val_loss: 2.7322 - val_acc: 0.3352
#
# Epoch 00041: val_loss did not improve from 2.69310
# Epoch 42/100
# 100/100 [==============================] - 49s 492ms/step - loss: 1.4482 - acc: 0.6845 - val_loss: 2.7190 - val_acc: 0.3234
#
# Epoch 00042: val_loss did not improve from 2.69310
# Epoch 43/100
# 100/100 [==============================] - 52s 521ms/step - loss: 1.4149 - acc: 0.6885 - val_loss: 2.6809 - val_acc: 0.3395
#
# Epoch 00043: val_loss improved from 2.69310 to 2.68093, saving model to dogskind.model.weights.best.hdf5
# Epoch 44/100
# 100/100 [==============================] - 50s 500ms/step - loss: 1.4271 - acc: 0.6855 - val_loss: 2.6709 - val_acc: 0.3375
#
# Epoch 00044: val_loss improved from 2.68093 to 2.67095, saving model to dogskind.model.weights.best.hdf5
# Epoch 45/100
# 100/100 [==============================] - 50s 500ms/step - loss: 1.3883 - acc: 0.6930 - val_loss: 2.6914 - val_acc: 0.3291
#
# Epoch 00045: val_loss did not improve from 2.67095
# Epoch 46/100
# 100/100 [==============================] - 50s 500ms/step - loss: 1.4219 - acc: 0.6770 - val_loss: 2.6638 - val_acc: 0.3369
#
# Epoch 00046: val_loss improved from 2.67095 to 2.66377, saving model to dogskind.model.weights.best.hdf5
# Epoch 47/100
# 100/100 [==============================] - 50s 497ms/step - loss: 1.3911 - acc: 0.6865 - val_loss: 2.6267 - val_acc: 0.3358
#
# Epoch 00047: val_loss improved from 2.66377 to 2.62669, saving model to dogskind.model.weights.best.hdf5
# Epoch 48/100
# 100/100 [==============================] - 52s 522ms/step - loss: 1.3720 - acc: 0.6970 - val_loss: 2.6342 - val_acc: 0.3519
#
# Epoch 00048: val_loss did not improve from 2.62669
# Epoch 49/100
# 100/100 [==============================] - 52s 518ms/step - loss: 1.3494 - acc: 0.6890 - val_loss: 2.6134 - val_acc: 0.3501
#
# Epoch 00049: val_loss improved from 2.62669 to 2.61343, saving model to dogskind.model.weights.best.hdf5
# Epoch 50/100
# 100/100 [==============================] - 50s 503ms/step - loss: 1.3431 - acc: 0.6930 - val_loss: 2.6322 - val_acc: 0.3382
#
# Epoch 00050: val_loss did not improve from 2.61343
# Epoch 51/100
# 100/100 [==============================] - 50s 498ms/step - loss: 1.1168 - acc: 0.7690 - val_loss: 2.5996 - val_acc: 0.3573
#
# Epoch 00051: val_loss improved from 2.61343 to 2.59956, saving model to dogskind.model.weights.best.hdf5
# Epoch 52/100
# 100/100 [==============================] - 50s 498ms/step - loss: 1.1480 - acc: 0.7710 - val_loss: 2.6909 - val_acc: 0.3194
#
# Epoch 00052: val_loss did not improve from 2.59956
# Epoch 53/100
# 100/100 [==============================] - 49s 494ms/step - loss: 1.1105 - acc: 0.7680 - val_loss: 2.5951 - val_acc: 0.3447
#
# Epoch 00053: val_loss improved from 2.59956 to 2.59514, saving model to dogskind.model.weights.best.hdf5
# Epoch 54/100
# 100/100 [==============================] - 50s 504ms/step - loss: 1.1413 - acc: 0.7625 - val_loss: 2.6135 - val_acc: 0.3425
#
# Epoch 00054: val_loss did not improve from 2.59514
# Epoch 55/100
# 100/100 [==============================] - 49s 486ms/step - loss: 1.1130 - acc: 0.7665 - val_loss: 2.6082 - val_acc: 0.3386
#
# Epoch 00055: val_loss did not improve from 2.59514
# Epoch 56/100
# 100/100 [==============================] - 51s 508ms/step - loss: 1.1449 - acc: 0.7490 - val_loss: 2.5758 - val_acc: 0.3531
#
# Epoch 00056: val_loss improved from 2.59514 to 2.57581, saving model to dogskind.model.weights.best.hdf5
# Epoch 57/100
# 100/100 [==============================] - 52s 516ms/step - loss: 1.0955 - acc: 0.7640 - val_loss: 2.5979 - val_acc: 0.3536
#
# Epoch 00057: val_loss did not improve from 2.57581
# Epoch 58/100
# 100/100 [==============================] - 49s 492ms/step - loss: 1.1194 - acc: 0.7415 - val_loss: 2.5977 - val_acc: 0.3323
#
# Epoch 00058: val_loss did not improve from 2.57581
# Epoch 59/100
# 100/100 [==============================] - 50s 495ms/step - loss: 1.1207 - acc: 0.7615 - val_loss: 2.5731 - val_acc: 0.3579
#
# Epoch 00059: val_loss improved from 2.57581 to 2.57309, saving model to dogskind.model.weights.best.hdf5
# Epoch 60/100
# 100/100 [==============================] - 53s 528ms/step - loss: 1.1032 - acc: 0.7510 - val_loss: 2.5563 - val_acc: 0.3445
#
# Epoch 00060: val_loss improved from 2.57309 to 2.55632, saving model to dogskind.model.weights.best.hdf5
# Epoch 61/100
# 100/100 [==============================] - 50s 500ms/step - loss: 0.9162 - acc: 0.8205 - val_loss: 2.5839 - val_acc: 0.3448
#
# Epoch 00061: val_loss did not improve from 2.55632
# Epoch 62/100
# 100/100 [==============================] - 52s 518ms/step - loss: 0.8959 - acc: 0.8380 - val_loss: 2.5829 - val_acc: 0.3466
#
# Epoch 00062: val_loss did not improve from 2.55632
# Epoch 63/100
# 100/100 [==============================] - 50s 498ms/step - loss: 0.9021 - acc: 0.8170 - val_loss: 2.5855 - val_acc: 0.3469
#
# Epoch 00063: val_loss did not improve from 2.55632
# Epoch 64/100
# 100/100 [==============================] - 50s 504ms/step - loss: 0.9286 - acc: 0.8185 - val_loss: 2.5770 - val_acc: 0.3504
#
# Epoch 00064: val_loss did not improve from 2.55632
# Epoch 65/100
# 100/100 [==============================] - 50s 505ms/step - loss: 0.8873 - acc: 0.8210 - val_loss: 2.5599 - val_acc: 0.3542
#
# Epoch 00065: val_loss did not improve from 2.55632
# Epoch 66/100
# 100/100 [==============================] - 50s 503ms/step - loss: 0.9253 - acc: 0.8075 - val_loss: 2.5689 - val_acc: 0.3559
#
# Epoch 00066: val_loss did not improve from 2.55632
# Epoch 67/100
# 100/100 [==============================] - 50s 500ms/step - loss: 0.8719 - acc: 0.8165 - val_loss: 2.5941 - val_acc: 0.3731
#
# Epoch 00067: val_loss did not improve from 2.55632

# %%
model.load_weights('dogskind.model.weights.best.hdf5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c8ac84f8053> in <module>
# ----> 1 model.load_weights('dogskind.model.weights.best.hdf5')
#
# NameError: name 'model' is not defined

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')

model.evaluate_generator(test_generator,steps=17, max_queue_size=50, workers=1, use_multiprocessing=True, verbose=0)
# Out:
# Found 836 images belonging to 133 classes.
# [2.5492985248565674, 0.3647058829665184]

# %%
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2bde386f904> in <module>
#       2 mpl.use('Agg')
#       3 import matplotlib.pyplot as plt
# ----> 4 acc = history.history['acc']
#       5 val_acc = history.history['val_acc']
#       6 loss = history.history['loss']
#
# NameError: name 'history' is not defined

# %%
yaml_string = model.to_yaml()
with open('./0cp.yaml', 'w') as outfile:
    outfile.write(yaml_string)
