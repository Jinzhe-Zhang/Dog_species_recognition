# %%
import os, shutil
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
import tensorflow as tf
import keras.backend.tensorflow_backend as KTF
config = tf.ConfigProto(gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.4))
sess = tf.Session(config=config)
KTF.set_session(sess)
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from keras.models import model_from_yaml, load_model
from keras.preprocessing import image 
import numpy as np
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras import layers
from keras import models
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
from keras.applications import VGG16
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
import random

# %%
# with open('./0.yaml') as yamlfile:
#     model = model_from_yaml(yamlfile.read())
model=load_model('./dogskindresnettest-Copy1.model.weights.best.hdf5')
from keras import optimizers
# lr: float >= 0. 学习率 Learning rate

# momentum: float >= 0. 参数更新动量 parameter updates momentum

# decay: float >= 0. 学习率每次更新的下降率 Learning rate decay over each update

# nesterov: boolean. 是否应用 Nesterov 动量 whether to apply Nesterov momentum
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-6),
              metrics=['acc'])

# %%
base_dir = './dogImages'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'valid')
test_dir = os.path.join(base_dir, 'test')
train_plus_dir=os.path.join(base_dir, 'train_plus')
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(256, 256),
        batch_size=100,
        class_mode='categorical')

model.evaluate_generator(test_generator,steps=100, max_queue_size=50, workers=1, use_multiprocessing=True, verbose=1)
# Out:
# Found 836 images belonging to 133 classes.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-6-c5f6c06bde29> in <module>
#      11         class_mode='categorical')
#      12
# ---> 13 model.evaluate_generator(test_generator,steps=100, max_queue_size=50, workers=1, use_multiprocessing=True, verbose=1)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1470             workers=workers,
#    1471             use_multiprocessing=use_multiprocessing,
# -> 1472             verbose=verbose)
#    1473
#    1474     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     344                                  'or (x, y). Found: ' +
#     345                                  str(generator_output))
# --> 346             outs = model.test_on_batch(x, y, sample_weight=sample_weight)
#     347             outs = to_list(outs)
#     348             outs_per_batch.append(outs)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in test_on_batch(self, x, y, sample_weight)
#    1254             ins = x + y + sample_weights
#    1255         self._make_test_function()
# -> 1256         outputs = self.test_function(ins)
#    1257         return unpack_singleton(outputs)
#    1258
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# ResourceExhaustedError: OOM when allocating tensor with shape[100,64,128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node resnet50_1/conv1/convolution}} = Conv2D[T=DT_FLOAT, data_format="NCHW", dilations=[1, 1, 1, 1], padding="VALID", strides=[1, 1, 2, 2], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](resnet50_1/conv1/convolution-0-TransposeNHWCToNCHW-LayoutOptimizer, conv1_1/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 150x150
        target_size=(256, 256),
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(256, 256),
        batch_size=100,
        class_mode='categorical')
# Out:
# Found 6680 images belonging to 133 classes.
# Found 835 images belonging to 133 classes.

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=7) 
ImageFile.LOAD_TRUNCATED_IMAGES = True
checkpointer = ModelCheckpoint(filepath='dogskindresnetiterate.model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(train_generator,
      steps_per_epoch=100,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=50, 
      callbacks=[early_stopping,checkpointer], 
      verbose=1)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-14-8edc60bf46bc> in <module>
#       9       validation_steps=50,
#      10       callbacks=[early_stopping,checkpointer],
# ---> 11       verbose=1)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# FailedPreconditionError: Attempting to use uninitialized value res2a_branch2c/kernel
# 	 [[{{node res2a_branch2c/kernel/read}} = Identity[T=DT_FLOAT, _class=["loc:@training/RMSprop/Assign_25"], _device="/job:localhost/replica:0/task:0/device:GPU:0"](res2a_branch2c/kernel)]]
# 	 [[{{node metrics/acc/Mean/_569}} = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_17185_metrics/acc/Mean", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]

# %%
# if not os.path.exists(train_strenthen_dir):
#     shutil.copytree(train_plus_dir,train_strenthen_dir)
kind_dic=np.load('labels.npy').item()
for kind in os.listdir(train_plus_dir):
    pic_kind=kind_dic[kind]
    print (kind)
    kind_dir=os.path.join(train_plus_dir, kind)
    wrong_num = 0
    for pic in os.listdir(kind_dir):
        if not pic.endswith(".jpg"):
            continue
        pic_dir=os.path.join(kind_dir, pic)
        img = image.load_img(pic_dir, target_size=(256,256))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        result = model.predict_classes(x)
        print ("    ",pic,result[0],pic_kind)
        if pic.startswith('pic_plus') and pic_kind==result[0]:
            print ("    right")
        else:
            print ("    wrong")
#             os.remove(pic_dir)
#             wrong_num+=1
#     parent_pics=[os.path.join(kind_dir, one) for one in os.listdir(kind_dir) if one.endswith(".jpg") and not one.startswith('pic_plus')]
#     for pic_dir in range(wrong_num):
#         print (pic_dir)
#         new_img = load_img(random.choice(parent_pics))
#         new_img = img_to_array(new_img)
#         new_img = np.expand_dims(new_img, axis=0)
#         aug = ImageDataGenerator(rotation_range=30, 
#                                  width_shift_range=0.1,
#                                  height_shift_range=0.1, 
#                                  shear_range=0.1, 
#                                  zoom_range=0.2,
#                                  horizontal_flip=True, 
#                                  fill_mode="nearest")
#         imageGen = aug.flow(new_img, batch_size=1, 
#                             save_to_dir=kind_dir,
#                             save_prefix="pic_plus2", 
#                             save_format="jpg")
#         for a in imageGen:
#             break
# Out:
# 064.English_toy_spaniel
#      pic_plus_0_1243.jpg 56 63
#     wrong
#      pic_plus_0_6169.jpg 56 63
#     wrong
#      pic_plus_0_8897.jpg 56 63
#     wrong
#      pic_plus_0_3452.jpg 56 63
#     wrong
#      pic_plus_0_5641.jpg 56 63
#     wrong
#      English_toy_spaniel_04519.jpg 56 63
#     wrong
#      pic_plus_0_1514.jpg 56 63
#     wrong
#      pic_plus_0_8529.jpg 56 63
#     wrong
#      English_toy_spaniel_04536.jpg 56 63
#     wrong
#      pic_plus_0_3277.jpg 56 63
#     wrong
#      pic_plus_0_8223.jpg 38 63
#     wrong
#      pic_plus_0_134.jpg 56 63
#     wrong
#      pic_plus_0_8236.jpg 56 63
#     wrong
#      pic_plus_0_4671.jpg 56 63
#     wrong
#      pic_plus_0_9394.jpg 56 63
#     wrong
#      pic_plus_0_7853.jpg 56 63
#     wrong
#      pic_plus_0_4710.jpg 56 63
#     wrong
#      pic_plus_0_4527.jpg 56 63
#     wrong
#      pic_plus_0_6601.jpg 123 63
#     wrong
#      pic_plus_0_8397.jpg 56 63
#     wrong
#      pic_plus_0_5904.jpg 38 63
#     wrong
#      pic_plus_0_7849.jpg 56 63
#     wrong
#      pic_plus_0_5128.jpg 56 63
#     wrong
#      pic_plus_0_7175.jpg 56 63
#     wrong
#      pic_plus_0_1865.jpg 56 63
#     wrong
#      pic_plus_0_3642.jpg 56 63
#     wrong
#      pic_plus_0_3450.jpg 56 63
#     wrong
#      pic_plus_0_3530.jpg 56 63
#     wrong
#      pic_plus_0_3488.jpg 56 63
#     wrong
#      pic_plus_0_4493.jpg 101 63
#     wrong
#      pic_plus_0_2219.jpg 56 63
#     wrong
#      pic_plus_0_6262.jpg 56 63
#     wrong
#      pic_plus_0_515.jpg 56 63
#     wrong
#      pic_plus_0_5583.jpg 56 63
#     wrong
#      pic_plus_0_3660.jpg 56 63
#      pic_plus_0_6214.jpg 56 11
#     wrong
#      pic_plus_0_6180.jpg 56 11
#     wrong
#      pic_plus_0_6224.jpg 56 11
#     wrong
#      pic_plus_0_4143.jpg 56 11
#     wrong
#      Australian_shepherd_00838.jpg 56 11
#     wrong
#      pic_plus_0_8336.jpg 56 11
#     wrong
#      Australian_shepherd_00875.jpg 56 11
#     wrong
#      pic_plus_0_9312.jpg 56 11
#     wrong
#      Australian_shepherd_00850.jpg 56 11
#     wrong
#      pic_plus_0_7975.jpg 123 11
#     wrong
#      pic_plus_0_4864.jpg 56 11
#     wrong
#      pic_plus_0_6074.jpg 56 11
#     wrong
#      pic_plus_0_4559.jpg 56 11
#     wrong
#      pic_plus_0_1957.jpg 56 11
#     wrong
#      pic_plus_0_5479.jpg 56 11
#     wrong
#      pic_plus_0_8364.jpg 56 11
#     wrong
#      pic_plus_0_6052.jpg 56 11
#     wrong
#      pic_plus_0_2857.jpg 56 11
#     wrong
#      pic_plus_0_8070.jpg 56 11
#     wrong
#      Australian_shepherd_00813.jpg 101 11
#     wrong
#      Australian_shepherd_00834.jpg 56 11
#     wrong
#      pic_plus_0_356.jpg 56 11
#     wrong
#      Australian_shepherd_00859.jpg 56 11
#     wrong
#      pic_plus_0_4226.jpg 56 11
#     wrong
#      pic_plus_0_8580.jpg 38 11
#     wrong
#      pic_plus_0_900.jpg 56 11
#     wrong
#      pic_plus_0_6487.jpg 56 11
#     wrong
#      pic_plus_0_3738.jpg 56 11
#     wrong
#      pic_plus_0_6475.jpg 56 11
#     wrong
#      pic_plus_0_4517.jpg 56 11
#     wrong
#      Australian_shepherd_00840.jpg 123 11
#     wrong
#      pic_plus_0_3641.jpg 56 11
#     wrong
#      pic_plus_0_3693.jpg 56 11
#     wrong
#      pic_plus_0_5843.jpg 56 11
#     wrong
#      pic_plus_0_432.jpg 56 11
#     wrong
#      pic_plus_0_3388.jpg 56 11
#     wrong
#      pic_plus_0_9562.jpg 56 11
#     wrong
#      Australian_shepherd_00811.jpg 56 11
#     wrong
#      pic_plus_0_2970.jpg 56 11
#     wrong
#      Australian_shepherd_00821.jpg 56 11
#     wrong
#      pic_plus_0_591.jpg 56 11
#     wrong
#      pic_plus_0_8382.jpg 56 11
#     wrong
#      Australian_shepherd_00810.jpg 56 11
#     wrong
#      Australian_shepherd_00826.jpg 123 11
#     wrong
#      pic_plus_0_7806.jpg 56 11
#     wrong
#      pic_plus_0_6640.jpg 56 11
#     wrong
#      Australian_shepherd_00856.jpg 56 11
#     wrong
#      pic_plus_0_6744.jpg 56 11
#     wrong
#      pic_plus_0_1308.jpg 56 11
#     wrong
#      pic_plus_0_2946.jpg 56 11
#     wrong
#      Australian_shepherd_00824.jpg 56 11
#     wrong
#      pic_plus_0_1649.jpg 56 11
#     wrong
# 058.Dandie_dinmont_terrier
#      Dandie_dinmont_terrier_04123.jpg 101 57
#     wrong
#      pic_plus_0_5071.jpg 56 57
#     wrong
#      Dandie_dinmont_terrier_
#     wrong
#      German_pinscher_04842.jpg 56 69
#     wrong
#      German_pinscher_04840.jpg 56 69
#     wrong
#      pic_plus_0_7056.jpg 56 69
#     wrong
#      pic_plus_0_6021.jpg 56 69
#     wrong
#      pic_plus_0_3281.jpg 123 69
#     wrong
#      pic_plus_0_1984.jpg 56 69
#     wrong
#      pic_plus_0_8219.jpg 123 69
#     wrong
#      pic_plus_0_2322.jpg 56 69
#     wrong
#      German_pinscher_04858.jpg 56 69
#     wrong
#      pic_plus_0_6690.jpg 56 69
#     wrong
#      pic_plus_0_8871.jpg 56 69
#     wrong
#      pic_plus_0_7287.jpg 56 69
#     wrong
#      pic_plus_0_1927.jpg 56 69
#     wrong
#      pic_plus_0_2252.jpg 56 69
#     wrong
#      pic_plus_0_95.jpg 56 69
#     wrong
#      German_pinscher_04835.jpg 56 69
#     wrong
#      pic_plus_0_1377.jpg 56 69
#     wrong
#      German_pinscher_04855.jpg 56 69
#     wrong
#      pic_plus_0_926.jpg 56 69
#     wrong
#      pic_plus_0_5215.jpg 56 69
#     wrong
#      German_pinscher_04829.jpg 56 69
#     wrong
#      pic_plus_0_8946.jpg 56 69
#     wrong
#      pic_plus_0_1507.jpg 56 69
#     wrong
#      pic_plus_0_2408.jpg 56 69
#     wrong
# 085.Irish_red_and_white_setter
#      Irish_red_and_white_setter_05779.jpg 56 84
#     wrong
#      pic_plus_0_6296.jpg 56 84
#     wrong
#      pic_plus_0_3024.jpg 123 84
#     wrong
#      pic_plus_0_4981.jpg 56 84
#     wrong
#      pic_plus_0_3367.jpg 38 84
#     wrong
#      Irish_red_and_white_setter_05762.jpg 56 84
#     wrong
#      pic_plus_0_1325.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05806.jpg 101 84
#     wrong
#      pic_plus_0_1213.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05803.jpg 123 84
#     wrong
#      Irish_red_and_white_setter_05793.jpg 56 84
#     wrong
#      pic_plus_0_9200.jpg 101 84
#     wrong
#      pic_plus_0_3028.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05769.jpg 123 84
#     wrong
#      pic_plus_0_6434.jpg 56 84
#     wrong
#      pic_plus_0_5315.jpg 56 84
#     wrong
#      pic_plus_0_909.jpg 56 84
#     wrong
#      pic_plus_0_7006.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05786.jpg 101 84
#     wrong
#      pic_plus_0_881.jpg 56 84
#     wrong
#      pic_plus_0_7845.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05787.jpg 56 84
#     wrong
#      pic_plus_0_9864.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05805.jpg 56 84
#     wrong
#      pic_plus_0_4833.jpg 56 84
#     wrong
#      pic_plus_0_169.jpg 56 84
#     wrong
#      pic_plus_0_5841.jpg 56 84
#     wrong
#      pic_plus_0_2061.jpg 56 84
#     wrong
#      pic_plus_0_3512.jpg 123 84
#     wrong
#      Irish_red_and_white_setter_05763.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05782.jpg 56 84
#     wrong
#      pic_plus_0_8770.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05785.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05774.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05783.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05777.jpg 56 84
#     wrong
#      pic_plus_0_1543.jpg 56 84
#     wrong
#      pic_plus_0_9696.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05781.jpg 123 84
#     wrong
#      pic_plus_0_2594.jpg 56 84
#     wrong
#      pic_plus_0_3862.jpg 56 84
#     wrong
#      pic_plus_0_863.jpg 56 84
#     wrong
#      pic_plus_0_1253.jpg 56 84
#     wrong
#      pic_plus_0_7216.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05765.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05767.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05776.jpg 56 84
#     wrong
#      pic_plus_0_8260.jpg 56 84
#     wrong
#      pic_plus_0_3126.jpg 56 84
#     wrong
#      pic_plus_0_6631.jpg 123 84
#     wrong
#      pic_plus_0_4722.jpg 123 84
#     wrong
#      Irish_red_and_white_setter_05784.jpg 56 84
#     wrong
#      pic_plus_0_3140.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05795.jpg 56 84
#     wrong
#      pic_plus_0_1002.jpg 56 84
#     wrong
#      pic_plus_0_4249.jpg 56 84
#     wrong
#      pic_plus_0_8200.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05788.jpg 56 84
#     wrong
#      pic_plus_0_4705.jpg 123 84
#     wrong
#      pic_plus_0_6240.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05807.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05798.jpg 56 84
#     wrong
#      pic_plus_0_3130.jpg 123 84
#     wrong
#      pic_plus_0_2793.jpg 122 84
#     wrong
#      Irish_red_and_white_setter_05771.jpg 123 84
#     wrong
#      pic_plus_0_1352.jpg 123 84
#     wrong
#      pic_plus_0_3971.jpg 101 84
#     wrong
#      pic_plus_0_4061.jpg 56 84
#     wrong
#      pic_plus_0_418.jpg 56 84
#     wrong
#      pic_plus_0_5195.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05801.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05790.jpg 67 84
#     wrong
#      pic_plus_0_321.jpg 56 84
#     wrong
#      pic_plus_0_258.jpg 123 84
#     wrong
#      pic_plus_0_3599.jpg 56 84
#     wrong
#      pic_plus_0_7585.jpg 56 84
#     wrong
#      pic_plus_0_6438.jpg 123 84
#     wrong
#      Irish_red_and_white_setter_05797.jpg 56 84
#     wrong
#      pic_plus_0_7093.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05799.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05802.jpg 56 84
#     wrong
#      pic_plus_0_3748.jpg 123 84
#     wrong
#      pic_plus_0_9627.jpg 67 84
#     wrong
#      pic_plus_0_9694.jpg 123 84
#     wrong
#      pic_plus_0_113.jpg 56 84
#     wrong
#      pic_plus_0_7333.jpg 123 84
#     wrong
#      Irish_red_and_white_setter_05780.jpg 123 84
#     wrong
#      pic_plus_0_8178.jpg 123 84
#     wrong
#      pic_plus_0_3116.jpg 123 84
#     wrong
#      Irish_red_and_white_setter_05791.jpg 56 84
#     wrong
#      pic_plus_0_5947.jpg 56 84
#     wrong
#      pic_plus_0_2262.jpg 123 84
#     wrong
#      pic_plus_0_4876.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05792.jpg 56 84
#     wrong
#      pic_plus_0_5422.jpg 123 84
#     wrong
#      pic_plus_0_2915.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05764.jpg 123 84
#     wrong
#      pic_plus_0_3752.jpg 56 84
#     wrong
#      pic_plus_0_1179.jpg 56 84
#     wrong
#      pic_plus_0_8502.jpg 56 84
#     wrong
#      pic_plus_0_4372.jpg 56 84
#     wrong
#      pic_plus_0_4735.jpg 56 84
#     wrong
#      pic_plus_0_6909.jpg 101 84
#     wrong
#      pic_plus_0_9162.jpg 123 84
#     wrong
#      pic_plus_0_7906.jpg 56 84
#     wrong
#      pic_plus_0_1842.jpg 123 84
#     wrong
#      pic_plus_0_3181.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05768.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05794.jpg 56 84
#     wrong
#      Irish_red_and_white_setter_05804.jpg 56 84
#     wrong
#      pic_plus_0_2301.jpg 56 84
#     wrong
# 011.Australian_cattle_dog
#      pic_plus_0_1656.jpg 56 10
#     wrong
#      Australian_cattle_dog_00800.jpg 56 10
#     wrong
#      Australian_cattle_dog_00750.jpg 56 10
#     wrong
#      pic_plus_0_2419.jpg 56 10
#     wrong
#      pic_plus_0_3493.jpg 56 10
#     wrong
#      Australian_cattle_dog_00740.jpg 56 10
#     wrong
#      pic_plus_0_1785.jpg 56 10
#     wrong
#      pic_plus_0_2339.jpg 56 10
#     wrong
#      pic_plus_0_655.jpg 56 10
#     wrong
#      Australian_cattle_dog_00736.jpg 56 10
#     wrong
#      Australian_cattle_dog_00723.jpg 56 10
#     wrong
#      pic_plus_0_4835.jpg 123 10
#     wrong
#      pic_plus_0_7895.jpg 56 10
#     wrong
#      pic_plus_0_494.jpg 56 10
#     wrong
#      Australian_cattle_dog_00738.jpg 56 10
#     wrong
#      Australian_cattle_dog_00796.jpg 56 10
#     wrong
#      pic_plus_0_368.jpg 56 10
#     wrong
#      pic_plus_0_9560.jpg 56 10
#     wrong
#      pic_plus_0_9121.jpg 123 10
#     wrong
#      pic_plus_0_8243.jpg 56 10
#     wrong
#      pic_plus_0_7547.jpg 56 10
#     wrong
#      pic_plus_0_3081.jpg 56 10
#     wrong
#      pic_plus_0_9796.jpg 56 10
#     wrong
#      pic_plus_0_6933.jpg 56 10
#     wrong
#      Australian_cattle_dog_00742.jpg 56 10
#     wrong
#      pic_plus_0_8991.jpg 122 10
#     wrong
#      Australian_cattle_dog_00745.jpg 56 10
#     wrong
#      Australian_cattle_dog_00766.jpg 56 10
#     wrong
#      Australian_cattle_dog_00762.jpg 56 10
#     wrong
#      pic_plus_0_8436.jpg 56 10
#     wrong
#      pic_plus_0_8611.jpg 56 10
#     wrong
#      pic_plus_0_9249.jpg 56 10
#     wrong
#      Australian_cattle_dog_00753.jpg 56 10
#     wrong
#      pic_plus_0_8717.jpg 56 10
#     wrong
#      pic_plus_0_625.jpg 56 10
#     wrong
#      Australian_cattle_dog_00769.jpg 56 10
#     wrong
#      Australian_cattle_dog_00772.jpg 56 10
#     wrong
#      pic_plus_0_4191.jpg 56 10
#     wrong
#      Australian_cattle_dog_00724.jpg 56 10
#     wrong
#      pic_plus_0_7295.jpg 56 10
#     wrong
#      Australian_cattle_dog_00760.jpg 56 10
#     wrong
#      pic_plus_0_5224.jpg 56 10
#     wrong
#      pic_plus_0_5036.jpg 56 10
#     wrong
#      pic_plus_0_1574.jpg 56 10
#     wrong
#      pic_plus_0_8570.jpg 56 10
#     wrong
#      Australian_cattle_dog_00784.jpg 38 10
#     wrong
#      pic_plus_0_9138.jpg 56 10
#     wrong
#      pic_plus_0_8202.jpg 56 10
#     wrong
#      Australian_cattle_dog_00779.jpg 56 10
#     wrong
#      pic_plus_0_6455.jpg 56 10
#     wrong
#      pic_plus_0_7827.jpg 56 10
#     wrong
#      pic_plus_0_670.jpg 56 10
#     wrong
#      pic_plus_0_6899.jpg 56 10
#     wrong
#      Australian_cattle_dog_00783.jpg 56 10
#     wrong
#      pic_plus_0_4915.jpg 56 10
#     wrong
#      pic_plus_0_4441.jpg 56 10
#     wrong
#      Australian_cattle_dog_00795.jpg 56 10
#     wrong
#      pic_plus_0_5749.jpg 56 10
#     wrong
#      Australian_cattle_dog_00793.jpg 56 10
#     wrong
#      pic_plus_0_601.jpg 38 10
#     wrong
#      pic_plus_0_1027.jpg 56 10
#     wrong
#      Australian_cattle_dog_00778.jpg 56 10
#     wrong
#      pic_plus_0_8464.jpg 56 10
#     wrong
#      pic_plus_0_6231.jpg 56 10
#     wrong
#      Australian_cattle_dog_00731.jpg 56 10
#     wrong
#      pic_plus_0_8127.jpg 123 10
#     wrong
#      pic_plus_0_3143.jpg 56 10
#     wrong
#      pic_plus_0_551.jpg 56 10
#     wrong
#      pic_plus_0_3713.jpg 56 10
#     wrong
#      pic_plus_0_138.jpg 56 10
#     wrong
#      pic_plus_0_5461.jpg 56 10
#     wrong
#      Australian_cattle_dog_00797.jpg 123 10
#     wrong
#      pic_plus_0_1222.jpg 56 10
#     wrong
#      pic_plus_0_5588.jpg 56 10
#     wrong
#      pic_plus_0_8503.jpg 56 10
#     wrong
#      pic_plus_0_534.jpg 56 10
#     wrong
#      pic_plus_0_6817.jpg 56 10
#     wrong
#      Australian_cattle_dog_00774.jpg 122 10
#     wrong
#      pic_plus_0_8160.jpg 56 10
#     wrong
#      Australian_cattle_dog_00759.jpg 56 10
#     wrong
#      pic_plus_0_9330.jpg 56 10
#     wrong
#      pic_plus_0_8121.jpg 56 10
#     wrong
#      pic_plus_0_109.jpg 56 10
#     wrong
#      pic_plus_0_4453.jpg 56 10
#     wrong
#      Australian_cattle_dog_00768.jpg 56 10
#     wrong
#      pic_plus_0_4111.jpg 56 10
#     wrong
#      pic_plus_0_9810.jpg 56 10
#     wrong
#      pic_plus_0_2603.jpg 56 10
#     wrong
#      pic_plus_0_2966.jpg 56 10
#     wrong
#      pic_plus_0_4255.jpg 56 10
#     wrong
#      Australian_cattle_dog_00776.jpg 56 10
#     wrong
#      pic_plus_0_8943.jpg 56 10
#     wrong
#      pic_plus_0_6714.jpg 56 10
#     wrong
#      pic_plus_0_6664.jpg 56 10
#     wrong
#      Australian_cattle_dog_00754.jpg 123 10
#     wrong
#      pic_plus_0_447.jpg 56 10
#     wrong
#      pic_plus_0_5340.jpg 56 10
#     wrong
#      Australian_cattle_dog_00764.jpg 123 10
#     wrong
#      pic_plus_0_2210.jpg 0 10
#     wrong
#      pic_plus_0_380.jpg 56 10
#     wrong
#      pic_plus_0_6703.jpg 56 10
#     wrong
#      Australian_cattle_dog_00752.jpg 56 10
#     wrong
#      Australian_cattle_dog_00725.jpg 56 10
#     wrong
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ac0876da9618> in <module>
#      14         x = image.img_to_array(img)
#      15         x = np.expand_dims(x, axis=0)
# ---> 16         result = model.predict_classes(x)
#      17         print ("    ",pic,result[0],pic_kind)
#      18         if pic.startswith('pic_plus') and pic_kind==result[0]:
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/sequential.py in predict_classes(self, x, batch_size, verbose)
#     265             A numpy array of class predictions.
#     266         """
# --> 267         proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     268         if proba.shape[-1] > 1:
#     269             return proba.argmax(axis=-1)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
total=0
right=0
kind_dic=np.load('labels.npy').item()
for kind in os.listdir(test_dir):
    kind_total=0
    kind_right=0
    pic_kind=kind_dic[kind]
    print (kind)
    kind_dir=os.path.join(test_dir, kind)
    wrong_num = 0
    for pic in os.listdir(kind_dir):
        if not pic.endswith(".jpg"):
            continue
        pic_dir=os.path.join(kind_dir, pic)
        img = image.load_img(pic_dir, target_size=(256,256))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        result = model.predict_classes(x)
        print ("    ",pic,result[0],pic_kind)
        kind_total+=1
        if pic_kind==result[0]:
            print ("    right")
            kind_right+=1
        else:
            print ("    wrong")
    print("kind_accuracy:",kind_right*1.0/kind_total)
    total+=kind_total
    right+=kind_right
#             os.remove(pic_dir)
#             wrong_num+=1
#     parent_pics=[os.path.join(kind_dir, one) for one in os.listdir(kind_dir) if one.endswith(".jpg") and not one.startswith('pic_plus')]
#     for pic_dir in range(wrong_num):
#         print (pic_dir)
#         new_img = load_img(random.choice(parent_pics))
#         new_img = img_to_array(new_img)
#         new_img = np.expand_dims(new_img, axis=0)
#         aug = ImageDataGenerator(rotation_range=30, 
#                                  width_shift_range=0.1,
#                                  height_shift_range=0.1, 
#                                  shear_range=0.1, 
#                                  zoom_range=0.2,
#                                  horizontal_flip=True, 
#                                  fill_mode="nearest")
#         imageGen = aug.flow(new_img, batch_size=1, 
#                             save_to_dir=kind_dir,
#                             save_prefix="pic_plus2", 
#                             save_format="jpg")
#         for a in imageGen:
#             break
print ("total_accuracy:",right, total,right*1.0/total)
